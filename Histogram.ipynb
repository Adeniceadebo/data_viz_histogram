# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df_income_distribution = pd.read_csv('income_distribution_data.csv')
df_income_distribution
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(8, 6))
plt.hist(df_income_distribution['Income'], bins=8, color='blue', edgecolor='none')
plt.title('Income Distribution by Demographic Factors', fontsize=14, fontweight='bold')
plt.xlabel('Income', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
sns.despine()
plt.savefig('income_distribution_plot.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 sns.set_theme(style='whitegrid')
#       2 plt.figure(figsize=(8, 6))
# ----> 3 plt.hist(df_income_distribution['Income'], bins=8, color='blue', edgecolor='name')
#       4 plt.title('Income Distribution by Demographic Factors', fontsize=14, fontweight='bold')
#       5 plt.xlabel('Income', fontsize=12)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3440, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3415 @_copy_docstring_and_deprecators(Axes.hist)
#    3416 def hist(
#    3417     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3438     BarContainer | Polygon | list[BarContainer | Polygon],
#    3439 ]:
# -> 3440     return gca().hist(
#    3441         x,
#    3442         bins=bins,
#    3443         range=range,
#    3444         density=density,
#    3445         weights=weights,
#    3446         cumulative=cumulative,
#    3447         bottom=bottom,
#    3448         histtype=histtype,
#    3449         align=align,
#    3450         orientation=orientation,
#    3451         rwidth=rwidth,
#    3452         log=log,
#    3453         color=color,
#    3454         label=label,
#    3455         stacked=stacked,
#    3456         **({"data": data} if data is not None else {}),
#    3457         **kwargs,
#    3458     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7154, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7152 if patch:
#    7153     p = patch[0]
# -> 7154     p._internal_update(kwargs)
#    7155     if lbl is not None:
#    7156         p.set_label(lbl)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/patches.py:385, in Patch.set_edgecolor(self, color)
#     377 """
#     378 Set the patch edge color.
#     379
#    (...)
#     382 color : :mpltype:`color` or None
#     383 """
#     384 self._original_edgecolor = color
# --> 385 self._set_edgecolor(color)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/patches.py:371, in Patch._set_edgecolor(self, color)
#     368         color = 'none'
#     369         set_hatch_color = False
# --> 371 self._edgecolor = colors.to_rgba(color, self._alpha)
#     372 if set_hatch_color:
#     373     self._hatch_color = self._edgecolor
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/colors.py:391, in _to_rgba_no_colorcycle(c, alpha)
#     387             raise ValueError(
#     388                 f"Invalid string grayscale value {orig_c!r}. "
#     389                 f"Value must be within 0-1 range")
#     390         return c, c, c, alpha if alpha is not None else 1.
# --> 391     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     392 # turn 2-D array into 1-D array
#     393 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'name'
